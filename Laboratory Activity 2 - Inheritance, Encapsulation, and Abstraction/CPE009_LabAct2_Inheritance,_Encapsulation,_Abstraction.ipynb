# %% [markdown]
# <a href="https://colab.research.google.com/github/jgvroallos/OOP-CPE009B-CPE21S4/blob/main/CPE009_LabAct2_Inheritance%2C_Encapsulation%2C_Abstraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Character

# %%
class Character():
  def __init__(self, username):
    self.__username = username
    self.__hp = 100
    self.__mana = 100
    self.__damage = 5
    self.__str = 0
    self.__vit = 0
    self.__int = 0
    self.__agi = 0

  def getUsername(self):
    return self.__username

  def setUsername(self, new_username):
    self.__username = new_username

  def getHp(self):
    return self.__hp

  def setHp(self, new_hp):
    self.__hp = new_hp

  def getDamage(self):
    return self.__damage

  def setDamage(self, new_damage):
    self.__damage = new_damage

  def getStr(self):
    return self.__str

  def setStr(self, new_str):
    self.__str = new_str

  def getVit(self):
    return self.__vit

  def setVit(self, new_vit):
    self.__vit = new_vit

  def getInt(self):
    return self.__int

  def setInt(self, new_int):
    self.__int = new_int

  def getAgi(self):
    return self.__agi

  def setAgi(self, new_agi):
    self.__agi = new_agi

  def reduceHp(self, damage_amount):
    self.__hp -= damage_amount

  def addHp(self, heal_amount):
    self.__hp += heal_amount

# %% [markdown]
# # Novice

# %%
#from Character import Character

class Novice(Character):
  def basicAttack(self, character):
    character.reduceHp(self.getDamage())
    print(f"{self.getUsername()} performed Basic Attack! -{self.getDamage()}")

# %% [markdown]
# # Swordsman

# %%
#from Novice import Novice

class Swordsman(Novice):
  def __init__(self, username):
    super().__init__(username)
    self.setStr(5)
    self.setVit(10)
    self.setHp(self.getHp()+ self.getVit())

  def slashAttack(self, character):
    self.new_damage = self.getDamage() + self.getStr()
    character.reduceHp(self.new_damage)
    print(f"{self.getUsername()} performed Slash Attack! -{self.new_damage}")

# %% [markdown]
# # Archer

# %%
#from Novice import Novice
import random

class Archer(Novice):
    def __init__(self, username):
      super().__init__(username)
      self.setAgi(5)
      self.setInt(5)
      self.setVit(5)
      self.setHp(self.getHp() + self.getVit())

    def rangedAttack(self, character):
      self.new_damage = self.getDamage() + random.randint(0, self.getInt())
      character.reduceHp(self.new_damage)
      print(f"{self.getUsername()} performed Ranged Attack! -{self.new_damage}")

# %% [markdown]
# # Magician

# %%
class Magician(Novice):
  def __init__(self, username):
    super().__init__(username)
    self.setInt(10)
    self.setVit(5)
    self.setHp(self.getHp() + self.getVit())

  def heal(self):
    self.addHp(self.getInt())
    print(f"{self.getUsername()} performed Heal! + {self.getInt()}")

  def magicAttack(self, character):
    self.new_damage = self.getDamage() + self.getInt()
    character.reduceHp(self.new_damage)
    print(f"{self.getUsername()} performed Magic Attack! -{self.new_damage}")

# %% [markdown]
# # Boss

# %%
class Boss(Swordsman, Archer, Magician):
  def __init__(self, username):
    super().__init__(username)
    self.setStr(10)
    self.setVit(25)
    self.setInt(5)
    self.setHp(self.getHp() + self.getVit())

# %% [markdown]
# # Test

# %%
#from Swordsman import Swordsman
#from Archer import Archer
#from Magician import Magician
#from Boss import Boss

Char1 = Swordsman("Royce")
Char2 = Magician("Archie")
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char1.slashAttack(Char2)
Char1.basicAttack(Char2)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char2.heal()
Char2.magicAttack(Char1)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")
# Out:
# Royce HP: 110
# Archie HP: 105
# Royce performed Slash Attack! -10
# Royce performed Basic Attack! -5
# Royce HP: 110
# Archie HP: 90
# Archie performed Heal! + 10
# Archie performed Magic Attack! -15
# Royce HP: 95
# Archie HP: 100

# %%
#from Swordsman import Swordsman
#from Archer import Archer
#from Magician import Magician
#from Boss import Boss

Char1 = Swordsman("Royce")
Char2 = Magician("Archie")
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char1.slashAttack(Char2)
Char1.basicAttack(Char2)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char2.heal()
Char2.slashAttack(Char1)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")
# Out:
# Royce HP: 110
# Archie HP: 105
# Royce performed Slash Attack! -10
# Royce performed Basic Attack! -5
# Royce HP: 110
# Archie HP: 90
# Archie performed Heal! + 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a8ac8841f39d> in <cell line: 17>()
#      15
#      16 Char2.heal()
# ---> 17 Char2.slashAttack(Char1)
#      18 print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
#      19 print(f"{Char2.getUsername()} HP: {Char2.getHp()}")
#
# AttributeError: 'Magician' object has no attribute 'slashAttack'

# %%
#from Swordsman import Swordsman
#from Archer import Archer
#from Magician import Magician
#from Boss import Boss

Char1 = Swordsman("Royce")
Char2 = Boss("Archie")
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char1.slashAttack(Char2)
Char1.basicAttack(Char2)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

Char2.heal()
Char2.basicAttack(Char1)
Char2.slashAttack(Char1)
Char2.rangedAttack(Char1)
Char2.magicAttack(Char1)
print(f"{Char1.getUsername()} HP: {Char1.getHp()}")
print(f"{Char2.getUsername()} HP: {Char2.getHp()}")

# %% [markdown]
# # Supplementary Activity

# %% [markdown]
# Game.py

# %%
from random import randint
#from Swordsman import Swordsman
#from Archer import Archer
#from Magician import Magician
#from Boss import Boss

class Game:
  def __init__(self):
    self.singleplay_wins = 0
    self.pvp_wins = 0
    self.roles = ["Swordsman", "Archer", "Magician"]

  def select_mode(self):
    mode = input("Select Game Mode: [1] Single Player, [2] PvP: ")
    if mode == "1":
      self.singleplay()
    elif mode == "2":
      self.pvp()
    else:
      print("Invalid Input")
      self.select_mode()

  def select_role(self, role):
    if role == "1":
      player = Swordsman(input(str("Enter player name: ")))
    elif role == "2":
      player = Archer(input(str("Enter player name: ")))
    elif role == "3":
      player = Magician(input(str("Enter player name: ")))
    else:
      print("Invalid Input. Selecting Novice...")
      player = Novice(input(str("Enter player name: ")))

    return player

  def start_game(self):
    print("Welcome to OOP RPG!")
    self.select_mode()

  def singleplay(self):
    player = Novice(input(str("Enter player name: ")))
    opponent = Boss("Monster")

    if self.singleplay_wins >= 2:
      print(f"Congratulations, {player.getUsername()}! Pick a class!\n")
      print("[1] Swordsman, [2] Archer, [3] Magician\n")
      role = input("Select Role: ")
      self.select_role(role)

    self.singleplay_session(player, opponent)11

    #print(f"Welcome {player.getUsername()}!")

  def pvp(self):
    pass

  def sp_player(self, player, opponent, player_choice):
    if player_choice == "1":
      player.basicAttack(opponent)

    else:
      print(f"{player.getUsername()} flinched!")

  def opponent_computer(self, player, opponent, opponent_choice):
    if opponent_choice == 0:
      opponent.basicAttack(player)

    elif opponent_choice == 1:
      opponent.slashAttack(player)

    elif opponent_choice == 2:
      opponent.rangedAttack(player)

    elif opponent_choice == 3:
      opponent.magicAttack(player)

    else:
      print("Opponent flinched!")

  def singleplay_session(self, player, opponent):
    print("\nWelcome to the battle!\n")

    while player.getHp() > 0 and opponent.getHp() > 0:
      print(f"{player.getUsername()} HP: {player.getHp()}")
      print(f"{opponent.getUsername()} HP: {opponent.getHp()}")

      player_choice = input("What to do? [1] Attack: ")
      print()
      self.sp_player(player, opponent, player_choice)

      opponent_choice = randint(0, 25)
      self.opponent_computer(player, opponent, opponent_choice)
      print()

    if player.getHp() <= 0:
      print(f"{opponent.getUsername()} won!")

    else:
      print(f"{player.getUsername()} won!")
      self.singleplay_wins += 1
      print(f"Total Singleplayer Wins: {self.singleplay_wins}")
      print("Returning to menu..\n\n")
      self.start_game()

if __name__ == "__main__":
  game = Game()
  game.start_game()
# Out:
# Welcome to OOP RPG!
# Select Game Mode: [1] Single Player, [2] PvP: 1
# Enter player name: qwerty
#
# Welcome to the battle!
#
# qwerty HP: 100
# Monster HP: 145
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 140
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 135
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 130
# What to do? [1] Attack: 5
#
# qwerty flinched!
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 130
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 125
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 120
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 115
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 110
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 100
# Monster HP: 105
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Magic Attack! -10
#
# qwerty HP: 90
# Monster HP: 100
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 95
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 90
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 85
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 80
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 75
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 70
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 65
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 60
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 55
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 90
# Monster HP: 50
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Slash Attack! -15
#
# qwerty HP: 75
# Monster HP: 45
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 75
# Monster HP: 40
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Basic Attack! -5
#
# qwerty HP: 70
# Monster HP: 35
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Basic Attack! -5
#
# qwerty HP: 65
# Monster HP: 30
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Magic Attack! -10
#
# qwerty HP: 55
# Monster HP: 25
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Monster performed Basic Attack! -5
#
# qwerty HP: 50
# Monster HP: 20
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 50
# Monster HP: 15
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 50
# Monster HP: 10
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty HP: 50
# Monster HP: 5
# What to do? [1] Attack: 1
#
# qwerty performed Basic Attack! -5
# Opponent flinched!
#
# qwerty won!
# Total Singleplayer Wins: 1
# Returning to menu..
#
#
# Welcome to OOP RPG!
# Select Game Mode: [1] Single Player, [2] PvP: 1
# Enter player name: 1
#
# Welcome to the battle!
#
# 1 HP: 100
# Monster HP: 145
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 100
# Monster HP: 140
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 100
# Monster HP: 135
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 100
# Monster HP: 130
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 100
# Monster HP: 125
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Monster performed Slash Attack! -15
#
# 1 HP: 85
# Monster HP: 120
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 115
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 110
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 105
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 100
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 95
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 90
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 85
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 80
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 75
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 70
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 65
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 60
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 55
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 50
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 45
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 40
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 35
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 30
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 25
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 20
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 15
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 10
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 HP: 85
# Monster HP: 5
# What to do? [1] Attack: 1
#
# 1 performed Basic Attack! -5
# Opponent flinched!
#
# 1 won!
# Total Singleplayer Wins: 2
# Returning to menu..
#
#
# Welcome to OOP RPG!
# Select Game Mode: [1] Single Player, [2] PvP: 1
# Enter player name: vincent
# Congratulations, vincent! Pick a class!
#
# [1] Swordsman, [2] Archer, [3] Magician
#
# Select Role: 2
# Enter player name: vincent
#
# Welcome to the battle!
#
# vincent HP: 100
# Monster HP: 145
# What to do? [1] Attack: 1
#
# vincent performed Basic Attack! -5
# Opponent flinched!
#
# vincent HP: 100
# Monster HP: 140
# What to do? [1] Attack: 2
#
# vincent flinched!
# Monster performed Ranged Attack! -8
#
# vincent HP: 92
# Monster HP: 140
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-e163086fa1f5> in <cell line: 111>()
#     111 if __name__ == "__main__":
#     112   game = Game()
# --> 113   game.start_game()
#     114
#     115
#
# <ipython-input-68-e163086fa1f5> in start_game(self)
#      39   def start_game(self):
#      40     print("Welcome to OOP RPG!")
# ---> 41     self.select_mode()
#      42
#      43   def singleplay(self):
#
# <ipython-input-68-e163086fa1f5> in select_mode(self)
#      15     mode = input("Select Game Mode: [1] Single Player, [2] PvP: ")
#      16     if mode == "1":
# ---> 17       self.singleplay()
#      18     elif mode == "2":
#      19       self.pvp()
#
# <ipython-input-68-e163086fa1f5> in singleplay(self)
#      51       self.select_role(role)
#      52
# ---> 53     self.singleplay_session(player, opponent)
#      54
#      55     #print(f"Welcome {player.getUsername()}!")
#
# <ipython-input-68-e163086fa1f5> in singleplay_session(self, player, opponent)
#     104       print(f"Total Singleplayer Wins: {self.singleplay_wins}")
#     105       print("Returning to menu..\n\n")
# --> 106       self.start_game()
#     107
#     108
#
# <ipython-input-68-e163086fa1f5> in start_game(self)
#      39   def start_game(self):
#      40     print("Welcome to OOP RPG!")
# ---> 41     self.select_mode()
#      42
#      43   def singleplay(self):
#
# <ipython-input-68-e163086fa1f5> in select_mode(self)
#      15     mode = input("Select Game Mode: [1] Single Player, [2] PvP: ")
#      16     if mode == "1":
# ---> 17       self.singleplay()
#      18     elif mode == "2":
#      19       self.pvp()
#
# <ipython-input-68-e163086fa1f5> in singleplay(self)
#      51       self.select_role(role)
#      52
# ---> 53     self.singleplay_session(player, opponent)
#      54
#      55     #print(f"Welcome {player.getUsername()}!")
#
# <ipython-input-68-e163086fa1f5> in singleplay_session(self, player, opponent)
#     104       print(f"Total Singleplayer Wins: {self.singleplay_wins}")
#     105       print("Returning to menu..\n\n")
# --> 106       self.start_game()
#     107
#     108
#
# <ipython-input-68-e163086fa1f5> in start_game(self)
#      39   def start_game(self):
#      40     print("Welcome to OOP RPG!")
# ---> 41     self.select_mode()
#      42
#      43   def singleplay(self):
#
# <ipython-input-68-e163086fa1f5> in select_mode(self)
#      15     mode = input("Select Game Mode: [1] Single Player, [2] PvP: ")
#      16     if mode == "1":
# ---> 17       self.singleplay()
#      18     elif mode == "2":
#      19       self.pvp()
#
# <ipython-input-68-e163086fa1f5> in singleplay(self)
#      51       self.select_role(role)
#      52
# ---> 53     self.singleplay_session(player, opponent)
#      54
#      55     #print(f"Welcome {player.getUsername()}!")
#
# <ipython-input-68-e163086fa1f5> in singleplay_session(self, player, opponent)
#      88       print(f"{opponent.getUsername()} HP: {opponent.getHp()}")
#      89
# ---> 90       player_choice = input("What to do? [1] Attack: ")
#      91       print()
#      92       self.sp_player(player, opponent, player_choice)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
